# %%
import numpy as np
import utils
from scipy import stats

# %%
rcParams['figure.figsize'] = (12, 8)
rcParams['font.size'] = 20
rcParams['lines.markersize'] = 10
rcParams['lines.linewidth'] = 2.0

# %%
x = np.linspace(0, 1, 1000)
plt.plot(x, utils.agent_type_rv('uniform').pdf(x), label='Uniform')
plt.plot(x, utils.agent_type_rv('normal').pdf(x), label='Truncated Normal')
plt.plot(x, utils.agent_type_rv('beta').pdf(x), label='Beta')
plt.legend(loc='best')
plt.xlabel('x')
plt.ylabel('PDF')
plt.suptitle('PDFs of agent type distributions')
