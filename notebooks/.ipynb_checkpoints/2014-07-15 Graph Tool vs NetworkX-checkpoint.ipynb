# %%
import sys; sys.path.append('/Users/brandonliu/Documents/Parkes/transitive-trust-models')
import networkx as nx
import graph_tool.all as gt
import numpy as np
import utils
import trust_graph as tg; reload(tg);

# %%
g1 = utils.random_weighted_graph(500, 0.5)
g2 = utils.gt_graph_from_nx(g1)

# %%
g1 = tg.TrustGraph.g50()
g2 = g1.gt_graph

# %%
g1 = nx.complete_graph(50)
weights = utils.agent_type_rv('uniform').rvs(size=g1.number_of_edges())
for i, e in enumerate(g1.edges_iter()):
    g1[e[0]][e[1]]['weight'] = weights[i]
g2 = utils.gt_graph_from_nx(g1)

# %% [markdown]
# ## 1. PageRank

# %%
timeit nx.pagerank_numpy(g1)
# Out:
# 1 loops, best of 3: 655 ms per loop

# %%
timeit gt.pagerank(g2)
# Out:
# 100 loops, best of 3: 7.47 ms per loop

# %% [markdown]
# ## 2. Maximum Flow

# %%
timeit nx.maximum_flow_value(g1, 0, 1, capacity='weight')
# Out:
# 100 loops, best of 3: 5.36 ms per loop

# %%
for i in xrange(50):
    for j in xrange(50):
        if i != j:
            print g2.vertex(i), g2.vertex(j)
            print gt.edmonds_karp_max_flow(g2, g2.vertex(i), g2.vertex(j), g2.edge_properties['weight'])
#             sys.stdout.flush()
#             print gt.push_relabel_max_flow(g2, g2.vertex(i), g2.vertex(j), g2.edge_properties['weight'])
#             print utils.fast_max_flow(g2, i, j)
# Out:
# 0 1
# <PropertyMap object with key type 'Edge' and value type 'double', for Graph 0x10e3b7f10, at 0x12fec0ed0>
# 0 2
# <PropertyMap object with key type 'Edge' and value type 'double', for Graph 0x10e3b7f10, at 0x12fec0ed0>
# 0 3
# <PropertyMap object with key type 'Edge' and value type 'double', for Graph 0x10e3b7f10, at 0x12fec0ed0>
# 0 4
# <PropertyMap object with key type 'Edge' and value type 'double', for Graph 0x10e3b7f10, at 0x12fec0ed0>
# 0 5
# <PropertyMap object with key type 'Edge' and value type 'double', for Graph 0x10e3b7f10, at 0x12fec0ed0>
# 0 6
# <PropertyMap object with key type 'Edge' and value type 'double', for Graph 0x10e3b7f10, at 0x12fec0ed0>
# 0 7
# <PropertyMap object with key type 'Edge' and value type 'double', for Graph 0x10e3b7f10, at 0x12fec0ed0>
# 0 8
# <PropertyMap object with key type 'Edge' and value type 'double', for Graph 0x10e3b7f10, at 0x12fec0ed0>
# 0 9
# ...

# %% [markdown]
# ## 3. Shortest Path

# %%
timeit nx.single_source_dijkstra(g1, 0)
# Out:
# 1000 loops, best of 3: 433 µs per loop

# %%
timeit gt.dijkstra_search(g2, g2.vertex(0), g2.edge_properties['weight'])
# Out:
# 100 loops, best of 3: 9.99 ms per loop

# %% [markdown]
# ## 4. Max Flow on a Trust Graph

# %%
g = tg.TrustGraph.g50()

# %%
import trust_models as tm; reload(tm)
import strategic_trust_models as stm; reload(stm);

# %%
timeit tm.max_flow(g)
# Out:
# fast max flow!
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# fast max flow!
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# fast max flow!
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# fast max flow!
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# 1 loops, best of 3: 3.93 s per loop

# %%
timeit tm.max_flow(g)
# Out:
# slow max flow!
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# slow max flow!
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# slow max flow!
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# slow max flow!
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# 1 loops, best of 3: 11.9 s per loop
