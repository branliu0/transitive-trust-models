# %%
import studies.efficiency as e
reload(e);

# %%
d = e.efficiency_by_edge_count(15, [3, 7, 10, 15, 20, 25], 25, 0)
# Out:
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# .
# .
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ..
# ...

# %%
e.plot(**d)

# %%
e.plot(**d)

# %%
d = e.efficiency_by_sybil_pct(20)
# Out:
# global_pagerank took 0.12 secs
# global_pagerank took 0.13 secs
# global_pagerank took 0.11 secs
# global_pagerank took 0.16 secs
# global_pagerank took 0.15 secs
# global_pagerank took 0.15 secs
# global_pagerank took 0.14 secs
# global_pagerank took 0.17 secs
# global_pagerank took 0.13 secs
# global_pagerank took 0.14 secs
# global_pagerank took 0.13 secs
# global_pagerank took 0.15 secs
# global_pagerank took 0.12 secs
# global_pagerank took 0.12 secs
# global_pagerank took 0.11 secs
# global_pagerank took 0.16 secs
# global_pagerank took 0.12 secs
# global_pagerank took 0.13 secs
# global_pagerank took 0.13 secs
# global_pagerank took 0.13 secs
# person_pagerank took 0.19 secs
# person_pagerank took 0.18 secs
# person_pagerank took 0.21 secs
# person_pagerank took 0.22 secs
# person_pagerank took 0.20 secs
# person_pagerank took 0.18 secs
# person_pagerank took 0.18 secs
# person_pagerank took 0.21 secs
# person_pagerank took 0.23 secs
# person_pagerank took 0.21 secs
# ...

# %%
e.plot(**d)

# %%
d = e.efficiency_by_sybil_pct(20, num_strategic=5)
# Out:
# global_pagerank took 0.09 secs
# global_pagerank took 0.08 secs
# global_pagerank took 0.10 secs
# global_pagerank took 0.10 secs
# global_pagerank took 0.10 secs
# global_pagerank took 0.10 secs
# global_pagerank took 0.09 secs
# global_pagerank took 0.11 secs
# global_pagerank took 0.10 secs
# global_pagerank took 0.09 secs
# global_pagerank took 0.10 secs
# global_pagerank took 0.10 secs
# global_pagerank took 0.10 secs
# global_pagerank took 0.09 secs
# global_pagerank took 0.10 secs
# global_pagerank took 0.11 secs
# global_pagerank took 0.09 secs
# global_pagerank took 0.09 secs
# global_pagerank took 0.10 secs
# global_pagerank took 0.10 secs
# person_pagerank took 0.16 secs
# person_pagerank took 0.16 secs
# person_pagerank took 0.17 secs
# person_pagerank took 0.18 secs
# person_pagerank took 0.22 secs
# person_pagerank took 0.16 secs
# person_pagerank took 0.17 secs
# person_pagerank took 0.16 secs
# person_pagerank took 0.17 secs
# person_pagerank took 0.16 secs
# ...

# %%
e.plot(**d)

# %%
from trust_graph import TrustGraph
g = TrustGraph(25, 'uniform', 'uniform', 10, 'noisy', 32)

# %%
import strategic_trust_models as stm
reload(stm);
from scipy import stats

# %%
ppr = stm.person_pagerank(g, 15, 0)

# %%
e.compute_informativeness(g.agent_types, ppr, False)
# Out:
# 0.65739130434782611

# %%
e.compute_efficiency(g.agent_types, ppr, False)
# Out:
# 0.57034516745106201

# %%
e.compute_informativeness(g.agent_types, stm.person_pagerank(g, 15, 0), False)
# Out:
# 0.026921739130434785

# %%
# Out:
# array([ 0.54063428,  0.54063428,  0.54063428,  0.54063428,  0.54063428,
#         0.54063428,  0.54063428,  0.54063428,  0.54063428,  0.63347338,
#         0.65952375,  0.54063428,  0.54063428,  0.61826492,  0.54063428,
#         0.54063428,  0.54063428,  0.67488485,  0.66067019,  0.65430153,
#         0.64399004,  0.66308275,  0.65948178,  0.54063428,  0.65341283])
