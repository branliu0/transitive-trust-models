# %%
import experiment_sets as es; reload(es);

# %%
eces = es.EdgeCountExperimentSet(50, 'uniform', 'uniform', 'noisy', 32, 5, '2014-02-04_sample32', [2, 3, 4, 5, 10, 15, 25, 30, 35, 40, 45, 49])

# %%
eces.run_parallel_experiments()
# Out:
# ....................................................................................................................................................................................................
# ....
# Experiment with val 2 added in 3.13 seconds
#
# Experiment with val 2 added in 3.11 seconds
# Experiment with val 3 added in 3.84 secondsExperiment with val 4 added in 4.62 seconds
# .
#
# ................................................................................................................................................................................................
# .....
# Experiment with val 3 added in 3.95 seconds.
# .
# Experiment with val 2 added in 3.20 seconds
# Experiment with val 3 added in 4.03 secondsExperiment with val 4 added in 4.81 seconds
# .
#
# .............................................................
# ../hitting_time/mat_hitting_time.py:32: RuntimeWarning: divide by zero encountered in double_scalars
# ...

# %%
eces.plot()
